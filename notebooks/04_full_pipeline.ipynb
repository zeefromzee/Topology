# %% [markdown]
# # Full Pipeline Demonstration
#
# This notebook demonstrates the complete end-to-end analysis pipeline for topological characterization of access structures.
#
# ## Overview
#
# The full pipeline takes access structures as input and produces comprehensive topological and cryptographic analysis results.
#
# ## Topics Covered
#
# 1. Pipeline configuration
# 2. Input preparation
# 3. Access structure validation
# 4. Complex construction
# 5. Topological invariant computation
# 6. Cryptographic analysis
# 7. Correlation analysis
# 8. Report generation
