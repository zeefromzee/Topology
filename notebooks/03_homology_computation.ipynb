# %% [markdown]
# # Homology Computation Examples
#
# This notebook demonstrates the computation of simplicial homology groups and topological invariants.
#
# ## Overview
#
# Homology groups are algebraic structures that encode topological features of a simplicial complex. This notebook shows how to compute and interpret them.
#
# ## Topics Covered
#
# 1. Boundary matrix construction
# 2. Homology group computation
# 3. Betti number calculation
# 4. Euler characteristic
# 5. Interpretation of results
